# %% [markdown]
# # Testing image methods

# %%
from src.haar_features import HaarLikeFeature as haar
from src.haar_features import featureType
from matplotlib.pyplot import imshow
from PIL import Image

# %%
ft1 = haar(featureType.TWO_VERTICAL, (2, 7), 13, 4,   1, 1 )
ft_img = ft1.draw_feature(res=(20,20), verbose=1)
# ft_img.show()
imshow(ft_img);
# Out:
# p0: (2, 7)  p1:(14, 8)  fill:green
# p0: (2, 9)  p1:(14, 10)  fill:red

# %%
img = Image.open('data/test/1/Ben_Affleck_8576_4744.png')
ft_img = ft1.draw_feature(img, res=(20,20))
imshow(ft_img);

# %%
ft2 = haar(featureType.TWO_VERTICAL, (2, 7), 12, 4,   1, 1 )
ft_img = ft2.draw_feature(img, res=(20,20), verbose=1)
# ft_img.show()
imshow(ft_img);
# Out:
# p0: (2, 7)  p1:(13, 8)  fill:green
# p0: (2, 9)  p1:(13, 10)  fill:red

# %%
ft3 = haar(featureType.TWO_VERTICAL, (1, 7), 14, 4,   1, 1 )
ft_img = ft3.draw_feature(img, res=(20,20), verbose=1)
# ft_img.show()
imshow(ft_img);
# Out:
# p0: (1, 7)  p1:(14, 8)  fill:green
# p0: (1, 9)  p1:(14, 10)  fill:red

# %%
ft3 = haar(featureType.TWO_VERTICAL, (2, 7), 14, 4,   1, 1 )
ft_img = ft3.draw_feature(img, res=(20,20), verbose=1)
# ft_img.show()
imshow(ft_img);
# Out:
# p0: (2, 7)  p1:(15, 8)  fill:green
# p0: (2, 9)  p1:(15, 10)  fill:red
