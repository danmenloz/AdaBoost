# %% [markdown]
# # Testing image methods

# %%
from src.haar_features import HaarLikeFeature as haar
from src.haar_features import featureType
from matplotlib.pyplot import imshow
from PIL import Image

# %%
ft = haar(featureType.TWO_VERTICAL, (5,5), 5, 10,   1, 1 )
ft_img = ft.draw_feature(res=(20,20))
# ft_img.show()
imshow(ft_img);
# Out:
# [(5, 5), (10, 10)]
# [(5, 10), (10, 15)]

# %%
ft2 = haar(featureType.TWO_VERTICAL, (12,5), 5, 10,   1, 1 )
ft2_img = ft2.draw_feature(ft_img, res=(20,20))
imshow(ft2_img);
# Out:
# [(12, 5), (17, 10)]
# [(12, 10), (17, 15)]

# %%
img = Image.open('data/test/1/Ashton_Kutcher_8022_4607.png')
ft2_img = ft2.draw_feature(img, res=(20,20))
imshow(ft2_img);
# Out:
# [(12, 5), (17, 10)]
# [(12, 10), (17, 15)]
